# %% [markdown]
# <a href="https://colab.research.google.com/github/codershiva91/Programming-Assignment-Module-2-/blob/main/Programming_Assignment_Module_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SARS-CoV-2 RNA Mathematical Modeling & 3D Visualization
#
# ## Objective
# This assignment aims to mathematically model the single-stranded RNA structure of the SARS-CoV-2 (Covid-19) virus and visualize it using a 3D plot. The visualization is based on a set of given parametric equations.
#
# ## Description
# - Images obtained from Thermo Fisher Scientific™ TEM and RNA schematics were used to understand the virus structure.
# - The RNA trajectory is modeled using the following parametric equations:

# %%
# import all the neccessary libraries
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# Import simps from its new location in scipy.integrate
from scipy.integrate import simpson

# %%
# STEP 1:
#now define the interval
t=np.linspace(0,3,1000)

# parametric equations
x=np.sqrt(8)*np.sqrt((1-np.cos(2*t))/np.sqrt(2))
y=np.sqrt(8)*np.sin(t+np.pi/2) #90 degree =pi/2 radians
z=t

# %%
#STEP 2:
#NOW CALCULATE CURVE LENGTH USING AARC LENGHT FORMULA
dx=np.gradient(x,t)
dy=np.gradient(y,t)
dz=np.gradient(z,t)
# Use simpson from scipy.integrate instead of np.simps
curve_length=simpson(np.sqrt(dx**2+dy**2+dz**2),t)
print(f"Estimated RNA structure length from t=0 to t=3: {curve_length:.4f} units")
# Out:
# Estimated RNA structure length from t=0 to t=3: 9.7437 units

# %%
#STEP 4:
fig=plt.figure(figsize=(10,7))
ax=fig.add_subplot(111,projection="3d")
ax.plot(x,y,z,color="red",linewidth=2)

# %% [markdown]
# **Visualization**

# %%
#STEP 4:
#Labels and view
ax.set_title("3D Structure of SARS-CoV-2 RNA", fontsize=14)
ax.set_xlabel("x(t)")
ax.set_ylabel("y(t)")
ax.set_zlabel("z(t)")
ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Conclusion** :
# we successfully conducted a mathematical and computational analysis of the SARS-CoV-2 (COVID-19) virus, focusing on the 3D visualization of its single-stranded RNA structure. Using the parametric equations provided, we employed Python and matplotlib to create a 3D line plot that visually represents the RNA trajectory over the time interval 0<t<3. The plot clearly demonstrated the continuous helical pattern typical of viral RNA.
